# %%
import pandas as pd

# %%
url = 'Data/City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month - City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
# 4          San Antonio-New Braunfels, TX        Bexar County    114794.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# ...

# %%
id_vars = df.columns[:8]
id_vars
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName'],
#       dtype='object')

# %%
largest_cities = pd.melt(df[df['SizeRank'].isin([0,1,2,3])], id_vars=id_vars, var_name='Date', value_name='Value')
largest_cities
# Out:
#       RegionID  SizeRank   RegionName RegionType StateName State  \
# 0         6181         0     New York       city        NY    NY
# 1        12447         1  Los Angeles       city        CA    CA
# 2        39051         2      Houston       city        TX    TX
# 3        17426         3      Chicago       city        IL    IL
# 4         6181         0     New York       city        NY    NY
# ...        ...       ...          ...        ...       ...   ...
# 1087     17426         3      Chicago       city        IL    IL
# 1088      6181         0     New York       city        NY    NY
# 1089     12447         1  Los Angeles       city        CA    CA
# 1090     39051         2      Houston       city        TX    TX
# 1091     17426         3      Chicago       city        IL    IL
#
#                                       Metro          CountyName        Date  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County  2000-01-31
# ...

# %%
import datetime

# %%
largest_cities['Date'] = pd.to_datetime(largest_cities['Date'], format='%Y-%m-%d')

# %%
largest_cities.dtypes
# Out:
# RegionID               int64
# SizeRank               int64
# RegionName            object
# RegionType            object
# StateName             object
# State                 object
# Metro                 object
# CountyName            object
# Date          datetime64[ns]
# Value                float64
# dtype: object

# %%
largest_cities
# Out:
#       RegionID  SizeRank   RegionName RegionType StateName State  \
# 0         6181         0     New York       city        NY    NY
# 1        12447         1  Los Angeles       city        CA    CA
# 2        39051         2      Houston       city        TX    TX
# 3        17426         3      Chicago       city        IL    IL
# 4         6181         0     New York       city        NY    NY
# ...        ...       ...          ...        ...       ...   ...
# 1087     17426         3      Chicago       city        IL    IL
# 1088      6181         0     New York       city        NY    NY
# 1089     12447         1  Los Angeles       city        CA    CA
# 1090     39051         2      Houston       city        TX    TX
# 1091     17426         3      Chicago       city        IL    IL
#
#                                       Metro          CountyName       Date  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County 2000-01-31
# ...

# %%
largest_cities = largest_cities.set_index('Date')
largest_cities
# Out:
#             RegionID  SizeRank   RegionName RegionType StateName State  \
# Date
# 2000-01-31      6181         0     New York       city        NY    NY
# 2000-01-31     12447         1  Los Angeles       city        CA    CA
# 2000-01-31     39051         2      Houston       city        TX    TX
# 2000-01-31     17426         3      Chicago       city        IL    IL
# 2000-02-29      6181         0     New York       city        NY    NY
# ...              ...       ...          ...        ...       ...   ...
# 2022-08-31     17426         3      Chicago       city        IL    IL
# 2022-09-30      6181         0     New York       city        NY    NY
# 2022-09-30     12447         1  Los Angeles       city        CA    CA
# 2022-09-30     39051         2      Houston       city        TX    TX
# 2022-09-30     17426         3      Chicago       city        IL    IL
#
#                                             Metro          CountyName  \
# Date
# ...

# %%
largest_cities.index
# Out:
# DatetimeIndex(['2000-01-31', '2000-01-31', '2000-01-31', '2000-01-31',
#                '2000-02-29', '2000-02-29', '2000-02-29', '2000-02-29',
#                '2000-03-31', '2000-03-31',
#                ...
#                '2022-07-31', '2022-07-31', '2022-08-31', '2022-08-31',
#                '2022-08-31', '2022-08-31', '2022-09-30', '2022-09-30',
#                '2022-09-30', '2022-09-30'],
#               dtype='datetime64[ns]', name='Date', length=1092, freq=None)

# %%
ts = largest_cities.groupby('RegionName').resample('M').sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21152\617433415.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ts = largest_cities.groupby('RegionName').resample('M').sum()
# C:\Users\User\AppData\Local\Temp\ipykernel_21152\617433415.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ts = largest_cities.groupby('RegionName').resample('M').sum()
# ...

# %%
ts
# Out:
#                        RegionID  SizeRank     Value
# RegionName Date
# Chicago    2000-01-31     17426         3  166139.0
#            2000-02-29     17426         3  166536.0
#            2000-03-31     17426         3  167368.0
#            2000-04-30     17426         3  168826.0
#            2000-05-31     17426         3  170499.0
# ...                         ...       ...       ...
# New York   2022-05-31      6181         0  768797.0
#            2022-06-30      6181         0  773944.0
#            2022-07-31      6181         0  777692.0
#            2022-08-31      6181         0  779960.0
#            2022-09-30      6181         0  781622.0
#
# [1092 rows x 3 columns]

# %%
unstacked = ts.unstack(level=0)
unstacked
# Out:
#            RegionID                              SizeRank                      \
# RegionName  Chicago Houston Los Angeles New York  Chicago Houston Los Angeles
# Date
# 2000-01-31    17426   39051       12447     6181        3       2           1
# 2000-02-29    17426   39051       12447     6181        3       2           1
# 2000-03-31    17426   39051       12447     6181        3       2           1
# 2000-04-30    17426   39051       12447     6181        3       2           1
# 2000-05-31    17426   39051       12447     6181        3       2           1
# ...             ...     ...         ...      ...      ...     ...         ...
# 2022-05-31    17426   39051       12447     6181        3       2           1
# 2022-06-30    17426   39051       12447     6181        3       2           1
# 2022-07-31    17426   39051       12447     6181        3       2           1
# 2022-08-31    17426   39051       12447     6181        3       2           1
# ...

# %%
from matplotlib.ticker import FuncFormatter

# %%
def thousands_formatter(x,pos):
    return f'{x/1000:0.f}K'

# %%
ax = unstacked['Value'].plot()
ax.yaxis.set_major_formatter(FuncFormatter(thousands_formatter))
# Out:
# Error in callback <function _draw_all_if_interactive at 0x00000265EFA3C0D0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# ...

# %%
# Question 1
ts.loc[pd.IndexSlice[:,'12 2008'],:]
# Out:
#                         RegionID  SizeRank     Value
# RegionName  Date
# Chicago     2008-12-31     17426         3  265306.0
# Houston     2008-12-31     39051         2  131283.0
# Los Angeles 2008-12-31     12447         1  469294.0
# New York    2008-12-31      6181         0  510309.0

# %%
# Question 2
chi_val = ts.loc['Chicago', 'Value']
hou_val = ts.loc['Houston', 'Value']
los_val = ts.loc['Los Angeles', 'Value']
new_val = ts.loc['New York', 'Value']
# make into DataFrame for .loc
comp_cols = pd.DataFrame({'Chicago':chi_val,
             'Houston':hou_val,
             'Los Angeles':los_val,
             'New York':new_val})
ts_compare = comp_cols.loc['11 2008':'12 2008']
ts_compare
# Out:
#              Chicago   Houston  Los Angeles  New York
# Date
# 2008-11-30  271059.0  132247.0     481905.0  514767.0
# 2008-12-31  265306.0  131283.0     469294.0  510309.0

# %%
diff_compare = ts_compare.diff()
diff_compare
# Out:
#             Chicago  Houston  Los Angeles  New York
# Date
# 2008-11-30      NaN      NaN          NaN       NaN
# 2008-12-31  -5753.0   -964.0     -12611.0   -4458.0

# %% [markdown]
# Here is how much home values dropped from Nov 2008 to Dec 2008.
